# %% [markdown]
# Table of contents
# 1. [Precinct Shapefile](#shapefile)
# 2. [Election Results](#electionresults)
# 3. [Joining Election Results to Precinct Shapefile](#joining)
# 4. [Comparison to VEST](#comparison)

# %% [markdown]
# **Import Python Packages**

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import geopandas as gp
import pathlib
import matplotlib.pyplot as plt
import maup
import requests

# %% [markdown]
# <a name="shapefile"></a>

# %% [markdown]
# # Precinct Shapefile

# %% [markdown]
# ## Load VEST's Final File

# %%
vest_shp = gp.read_file("./raw-from-source/vest_az_2016/az_2016.shp")

# %%
vest_shp.shape
# Out:
# (1469, 13)

# %%
vest_shp.head(1)
# Out:
#    PCTNUM PRECINCTNA CDE_COUNTY  G16PRERTRU  G16PREDCLI  G16PRELJOH  \
# 0  AP0002     ALPINE         AP         216          60          13
#
#    G16PREGSTE  G16PREOWRI  G16USSRMCC  G16USSDKIR  G16USSGSWI  G16USSOWRI  \
# 0           2           4         196          65          22           5
#
#                                             geometry
# 0  POLYGON ((-109.49567 33.65280, -109.49576 33.6...

# %%
vest_shp.boundary.plot()

# %% [markdown]
# ## Load Source Precinct File

# %% [markdown]
# VEST does not specify their source. This file is from Garrett Archer

# %%
precincts = gp.read_file("./raw-from-source/pct_2016/pct_2016.shp")

# %%
precincts.shape
# Out:
# (1469, 13)

# %%
precincts.head(1)
# Out:
#    PCTNUM PRECINCTNA CDE_COUNTY  G16PRERTRU  G16PREDCLI  G16PRELJOH  \
# 0  AP0002     ALPINE         AP         216          60          13
#
#    G16PREGSTE  G16PREOWRI  G16USSRMCC  G16USSDKIR  G16USSGSWI  G16USSOWRI  \
# 0           2           4         196          65          22           5
#
#                                             geometry
# 0  POLYGON ((-109.49567 33.65280, -109.49576 33.6...

# %%
precincts.boundary.plot()

# %% [markdown]
# ## Seeing if Source File is the same

# %% [markdown]
# Outer join the VEST's file and the raw precinct file on `pctnum`

# %%
vest_raw_joined = pd.merge(vest_shp,precincts,
                              left_on=['PCTNUM'],right_on=['PCTNUM'],
                              how='outer',indicator=True)

# %%
vest_raw_joined.groupby('_merge').count()
# Out:
#             PCTNUM  PRECINCTNA_x  CDE_COUNTY_x  G16PRERTRU_x  G16PREDCLI_x  \
# _merge
# left_only        0             0             0             0             0
# right_only       0             0             0             0             0
# both          1469          1469          1469          1469          1469
#
#             G16PRELJOH_x  G16PREGSTE_x  G16PREOWRI_x  G16USSRMCC_x  \
# _merge
# left_only              0             0             0             0
# right_only             0             0             0             0
# both                1469          1469          1469          1469
#
#             G16USSDKIR_x  ...  G16PRERTRU_y  G16PREDCLI_y  G16PRELJOH_y  \
# _merge                    ...
# left_only              0  ...             0             0             0
# right_only             0  ...             0             0             0
# both                1469  ...          1469          1469          1469
#
#             G16PREGSTE_y  G16PREOWRI_y  G16USSRMCC_y  G16USSDKIR_y  \
# _merge
# left_only              0             0             0             0
# right_only             0             0             0             0
# both                1469          1469          1469          1469
#
#             G16USSGSWI_y  G16USSOWRI_y  geometry_y
# _merge
# left_only              0             0           0
# right_only             0             0           0
# both                1469          1469        1469
#
# [3 rows x 25 columns]

# %%
#Want to check this in the "both" match as well as the shapefile match
first_check = vest_raw_joined[(vest_raw_joined["_merge"]=="both")]

pdv_shapes_elections_and_shapes = gp.GeoDataFrame(first_check, geometry='geometry_y')
vest_shapes_elections_and_shapes = gp.GeoDataFrame(first_check, geometry='geometry_x')

pdv_shapes_elections_and_shapes.crs=vest_shapes_elections_and_shapes.crs

# %%
pdv_shapes_elections_and_shapes.geom_almost_equals(vest_shapes_elections_and_shapes,
                                                   decimal=1).value_counts()
# Out:
# True    1469
# dtype: int64

# %% [markdown]
# So the VEST shapefile is exactly the same as the one we received from Garrett Archer, including election results as well. We'll proceed assuming that this file is the raw source, since we do not have another option

# %% [markdown]
# # Election Results

# %% [markdown]
# ## Reading in MEDSL Results

# %% [markdown]
# The SOS results are by county and would require quite a bit of processing to load all of them, so going to just try to use MEDSL results and see how close that gets.

# %% [markdown]
# ### Presidential Results

# %%
medsl_pres = pd.read_csv('./raw-from-source/medsl/2016-precinct-president/2016-precinct-president.csv', encoding='ISO-8859-1', low_memory = False)

# %%
medsl_pres.head(5)
# Out:
#    year stage  special    state state_postal  state_fips  state_icpsr  \
# 0  2016   gen    False  Alabama           AL           1           41
# 1  2016   gen    False  Alabama           AL           1           41
# 2  2016   gen    False  Alabama           AL           1           41
# 3  2016   gen    False  Alabama           AL           1           41
# 4  2016   gen    False  Alabama           AL           1           41
#
#       county_name  county_fips  county_ansi  ...  candidate_middle  \
# 0  Autauga County       1001.0     161526.0  ...               NaN
# 1  Autauga County       1001.0     161526.0  ...               NaN
# 2  Autauga County       1001.0     161526.0  ...               NaN
# 3  Autauga County       1001.0     161526.0  ...               NaN
# 4  Autauga County       1001.0     161526.0  ...               NaN
#
#    candidate_full candidate_suffix candidate_nickname candidate_fec  \
# 0             NaN              NaN                NaN     P00003392
# 1             NaN              NaN                NaN     P60012234
# 2             NaN              NaN                NaN     P20003984
# 3             NaN              NaN                NaN     P80001571
# 4             NaN              NaN                NaN           NaN
#
#                                 candidate_fec_name candidate_google  \
# 0  CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE              NaN
# 1                     JOHNSON, JOHN FITZGERALD MR.              NaN
# 2                                      STEIN, JILL              NaN
# 3              TRUMP, DONALD J. / MICHAEL R. PENCE              NaN
# 4                                              NaN              NaN
#
#   candidate_govtrack  candidate_icpsr candidate_maplight
# 0                NaN              NaN                NaN
# 1                NaN              NaN                NaN
# 2                NaN              NaN                NaN
# 3                NaN              NaN                NaN
# 4                NaN              NaN                NaN
#
# [5 rows x 37 columns]

# %%
az_pres = medsl_pres[medsl_pres['state_fips'] == 4].copy()

# %%
az_pres.to_csv('./raw-from-source/medsl_az_pres_2016.csv')

# %% [markdown]
# To figure out the names of the offices that we need in MEDSL's file:

# %%
az_pres.groupby(['office']).sum()
# Out:
#                   year  special  state_fips  state_icpsr  county_fips  \
# office
# US President  34836480      0.0       69120      1054080   69374535.0
#
#               county_ansi     county_lat   county_long  writein    votes  ...  \
# office                                                                    ...
# US President  524831590.0  577668.090185 -1.930417e+06   3456.0  2604639  ...
#
#               candidate_last  candidate_first  candidate_middle  \
# office
# US President             0.0              0.0               0.0
#
#               candidate_full  candidate_suffix  candidate_nickname  \
# office
# US President             0.0               0.0                 0.0
#
#               candidate_google  candidate_govtrack  candidate_icpsr  \
# office
# US President               0.0                 0.0              0.0
#
#               candidate_maplight
# office
# US President                 0.0
#
# [1 rows x 23 columns]

# %%
az_pres[az_pres.office.isin(['US President'])].groupby(['office','party','candidate']).sum()['votes']
# Out:
# office        party        candidate
# US President  democratic   Hillary Clinton    1161165
#               green        Jill Stein           34344
#               libertarian  Gary Johnson        106326
#               republican   Donald Trump       1252389
# Name: votes, dtype: int64

# %%
az_pres.loc[(az_pres.candidate == '[Write-in]')]['votes'].sum()
# Out:
# 50415

# %% [markdown]
# So the write-in in MEDSL includes write-in, McCullin, and Castle votes. See [wiki election results](https://en.wikipedia.org/wiki/2016_United_States_presidential_election_in_Arizona).

# %% [markdown]
# The write-in candidates were listed as party nonpartisan in the MEDSL results

# %%
az_pres.loc[az_pres['candidate'] == "[Write-in]", 'party'] = 'write_in'

# %%
az_pres[az_pres.office.isin(['US President'])].groupby(['office','party','candidate']).sum()['votes']
# Out:
# office        party        candidate
# US President  democratic   Hillary Clinton    1161165
#               green        Jill Stein           34344
#               libertarian  Gary Johnson        106326
#               republican   Donald Trump       1252389
#               write_in     [Write-in]           50415
# Name: votes, dtype: int64

# %% [markdown]
# ### Senate Results

# %%
medsl_uss = pd.read_csv('./raw-from-source/medsl/2016-precinct-senate/2016-precinct-senate.csv', encoding='ISO-8859-1', low_memory = False)

# %%
medsl_uss.head(5)
# Out:
#    year stage  special    state state_postal  state_fips  state_icpsr  \
# 0  2016   gen    False  Alabama           AL           1           41
# 1  2016   gen    False  Alabama           AL           1           41
# 2  2016   gen    False  Alabama           AL           1           41
# 3  2016   gen    False  Alabama           AL           1           41
# 4  2016   gen    False  Alabama           AL           1           41
#
#       county_name  county_fips  county_ansi  ...  candidate_middle  \
# 0  Autauga County       1001.0     161526.0  ...               NaN
# 1  Autauga County       1001.0     161526.0  ...               NaN
# 2  Autauga County       1001.0     161526.0  ...               NaN
# 3  Autauga County       1001.0     161526.0  ...               NaN
# 4  Autauga County       1001.0     161526.0  ...                C.
#
#       candidate_full candidate_suffix candidate_nickname candidate_fec  \
# 0                NaN              NaN                NaN           NaN
# 1                NaN              NaN                NaN           NaN
# 2                NaN              NaN                NaN           NaN
# 3                NaN              NaN                NaN     S6AL00302
# 4  Richard C. Shelby              NaN                NaN     S6AL00013
#
#               candidate_fec_name candidate_google candidate_govtrack  \
# 0                            NaN              NaN                NaN
# 1                            NaN              NaN                NaN
# 2                            NaN              NaN                NaN
# 3  CRUMPTON, RONALD (RON) STEVEN              NaN                NaN
# 4                            NaN     kg:/m/020yj1           300089.0
#
#    candidate_icpsr candidate_maplight
# 0              NaN                NaN
# 1              NaN                NaN
# 2              NaN                NaN
# 3              NaN                NaN
# 4          14659.0              608.0
#
# [5 rows x 37 columns]

# %%
az_uss = medsl_uss[medsl_uss['state_fips'] == 4].copy()

# %%
az_uss.to_csv('./raw-from-source/medsl_az_uss_2016.csv')

# %% [markdown]
# To figure out the names of the offices that we need in MEDSL's file:

# %%
az_uss.groupby(['office']).sum()
# Out:
#                year  special  state_fips  state_icpsr  county_fips  \
# office
# US Senate  27869184      0.0       55296       843264   55499628.0
#
#            county_ansi     county_lat   county_long  writein    votes  \
# office
# US Senate  419865272.0  462134.472148 -1.544334e+06   3456.0  2547042
#
#            candidate_suffix  candidate_govtrack  candidate_icpsr  \
# office
# US Senate               0.0        1.037045e+09       51974784.0
#
#            candidate_maplight
# office
# US Senate           2045952.0

# %%
az_uss[az_uss.office.isin(['US Senate'])].groupby(['office','party','candidate']).sum()['votes']
# Out:
# office     party       candidate
# US Senate  democratic  Ann Kirkpatrick    1031241
#            green       Gary Swing          138631
#            republican  John McCain        1359258
# Name: votes, dtype: int64

# %%
az_uss.loc[(az_uss.candidate == '[Write-in]')]['votes'].sum()
# Out:
# 17912

# %% [markdown]
# So it seems like maybe MEDSL has too many write-in votes for the senate election. [Ballotpedia](https://ballotpedia.org/United_States_Senate_election_in_Arizona,_2016) and [Wiki](https://en.wikipedia.org/wiki/2016_United_States_Senate_election_in_Arizona#General_election) both have it at 1,584 write-in votes.

# %% [markdown]
# The write-in candidates were listed as party nonpartisan in the MEDSL results

# %%
az_uss.loc[az_uss['candidate'] == "[Write-in]", 'party'] = 'write_in'

# %%
az_uss[az_uss.office.isin(['US Senate'])].groupby(['office','party','candidate']).sum()['votes']
# Out:
# office     party       candidate
# US Senate  democratic  Ann Kirkpatrick    1031241
#            green       Gary Swing          138631
#            republican  John McCain        1359258
#            write_in    [Write-in]           17912
# Name: votes, dtype: int64

# %% [markdown]
# ### Combine Presidential & Senate

# %%
az_pres.columns
# Out:
# Index(['year', 'stage', 'special', 'state', 'state_postal', 'state_fips',
#        'state_icpsr', 'county_name', 'county_fips', 'county_ansi',
#        'county_lat', 'county_long', 'jurisdiction', 'precinct', 'candidate',
#        'candidate_normalized', 'office', 'district', 'writein', 'party',
#        'mode', 'votes', 'candidate_opensecrets', 'candidate_wikidata',
#        'candidate_party', 'candidate_last', 'candidate_first',
#        'candidate_middle', 'candidate_full', 'candidate_suffix',
#        'candidate_nickname', 'candidate_fec', 'candidate_fec_name',
#        'candidate_google', 'candidate_govtrack', 'candidate_icpsr',
#        'candidate_maplight'],
#       dtype='object')

# %%
az_uss.columns
# Out:
# Index(['year', 'stage', 'special', 'state', 'state_postal', 'state_fips',
#        'state_icpsr', 'county_name', 'county_fips', 'county_ansi',
#        'county_lat', 'county_long', 'jurisdiction', 'precinct', 'candidate',
#        'candidate_normalized', 'office', 'district', 'writein', 'party',
#        'mode', 'votes', 'candidate_opensecrets', 'candidate_wikidata',
#        'candidate_party', 'candidate_last', 'candidate_first',
#        'candidate_middle', 'candidate_full', 'candidate_suffix',
#        'candidate_nickname', 'candidate_fec', 'candidate_fec_name',
#        'candidate_google', 'candidate_govtrack', 'candidate_icpsr',
#        'candidate_maplight'],
#       dtype='object')

# %%
az_elections = pd.concat([az_pres, az_uss])

# %%
az_elections.sample(5)
# Out:
#        year stage  special    state state_postal  state_fips  state_icpsr  \
# 23489  2016   gen    False  Arizona           AZ           4           61
# 29952  2016   gen    False  Arizona           AZ           4           61
# 36236  2016   gen    False  Arizona           AZ           4           61
# 25212  2016   gen    False  Arizona           AZ           4           61
# 18739  2016   gen    False  Arizona           AZ           4           61
#
#            county_name  county_fips  county_ansi  ...  candidate_middle  \
# 23489  Coconino County       4005.0      25443.0  ...               NaN
# 29952      Pima County       4019.0      25446.0  ...               NaN
# 36236   Yavapai County       4025.0      42809.0  ...               NaN
# 25212  Maricopa County       4013.0      37026.0  ...               NaN
# 18739      Gila County       4007.0      40471.0  ...               NaN
#
#        candidate_full candidate_suffix candidate_nickname candidate_fec  \
# 23489             NaN              NaN                NaN     P20003984
# 29952             NaN              NaN                NaN     P80001571
# 36236             NaN              NaN                NaN     P80001571
# 25212             NaN              NaN                NaN           NaN
# 18739             NaN              NaN                NaN     S6AZ00225
#
#                         candidate_fec_name candidate_google  \
# 23489                          STEIN, JILL              NaN
# 29952  TRUMP, DONALD J. / MICHAEL R. PENCE              NaN
# 36236  TRUMP, DONALD J. / MICHAEL R. PENCE              NaN
# 25212                                  NaN              NaN
# 18739               KIRKPATRICK, ANN LEILA              NaN
#
#       candidate_govtrack  candidate_icpsr candidate_maplight
# 23489                NaN              NaN                NaN
# 29952                NaN              NaN                NaN
# 36236                NaN              NaN                NaN
# 25212                NaN              NaN                NaN
# 18739                NaN              NaN                NaN
#
# [5 rows x 37 columns]

# %% [markdown]
# ## Pivoting MEDSL Election Results

# %% [markdown]
# Pivot the table by county and precinct

# %%
az_elections_pivot = az_elections.pivot_table(index = ['county_name','county_fips','precinct'],
                         columns = ['office','party'],
                        values = ['votes'],
                         aggfunc = 'sum')

# %% [markdown]
# Testing out dataset, investigating

# %%
az_elections_pivot.reset_index(inplace = True)

# %%
az_elections_pivot.columns = ['_'.join(filter(None, col)).replace(' ','_').replace('votes_','').lower() \
     for col in az_elections_pivot.columns]

# %%
az_elections_pivot.head(3)
# Out:
#      county_name  county_fips             precinct  us_president_democratic  \
# 0  Apache County       4001.0            ALPINE|02                       60
# 1  Apache County       4001.0  CANYON DE CHELLY|03                     1387
# 2  Apache County       4001.0            CHINLE|05                      678
#
#    us_president_green  us_president_libertarian  us_president_republican  \
# 0                   2                        13                      216
# 1                  32                        72                      143
# 2                  17                        38                       93
#
#    us_president_write_in  us_senate_democratic  us_senate_green  \
# 0                      4                    65               22
# 1                     51                  1499               45
# 2                     36                   721               24
#
#    us_senate_republican  us_senate_write_in
# 0                   196                   5
# 1                   188                   4
# 2                   127                   1

# %%
az_elections_pivot.columns
# Out:
# Index(['county_name', 'county_fips', 'precinct', 'us_president_democratic',
#        'us_president_green', 'us_president_libertarian',
#        'us_president_republican', 'us_president_write_in',
#        'us_senate_democratic', 'us_senate_green', 'us_senate_republican',
#        'us_senate_write_in'],
#       dtype='object')

# %%
az_elections_pivot.columns = [col.replace('us_president',
             'pre').replace('us_senate',
             'uss').replace('democratic',
             'd').replace('republican',
             'r').replace('green',
             'g').replace('write_in',
             'w').replace('libertarian',
             'l') for col in az_elections_pivot.columns]

# %%
az_elections_pivot.head()
# Out:
#      county_name  county_fips             precinct  pre_d  pre_g  pre_l  \
# 0  Apache County       4001.0            ALPINE|02     60      2     13
# 1  Apache County       4001.0  CANYON DE CHELLY|03   1387     32     72
# 2  Apache County       4001.0            CHINLE|05    678     17     38
# 3  Apache County       4001.0            CONCHO|09    228     11     44
# 4  Apache County       4001.0        CORNFIELDS|10    349      3     16
#
#    pre_r  pre_w  uss_d  uss_g  uss_r  uss_w
# 0    216      4     65     22    196      5
# 1    143     51   1499     45    188      4
# 2     93     36    721     24    127      1
# 3   1135     27    291    195    836     42
# 4     33     12    375      5     37      1

# %%
az_elections_pivot.sum().astype(str)
# Out:
# county_name    Apache CountyApache CountyApache CountyApache ...
# county_fips                                            5896966.0
# precinct       ALPINE|02CANYON DE CHELLY|03CHINLE|05CONCHO|09...
# pre_d                                                    1161165
# pre_g                                                      34344
# pre_l                                                     106326
# pre_r                                                    1252389
# pre_w                                                      50415
# uss_d                                                    1031241
# uss_g                                                     138631
# uss_r                                                    1359258
# uss_w                                                      17912
# dtype: object

# %% [markdown]
# Re-order the MEDSL columns in the pivot table to match VEST's ordering

# %%
az_elections_pivot = az_elections_pivot[['county_name', 'county_fips','precinct', 
 'pre_r','pre_d','pre_l','pre_g','pre_w','uss_r', 'uss_d', 'uss_g', 'uss_w',]]

# %% [markdown]
# Compare the totals from the MEDSL results to VEST's:

# %%
vest_cols = [col for col in vest_shp.columns if 'G16' in col]
medsl_cols = [col for col in az_elections_pivot.columns if col != 'county_name' and col != 'county_fips' and col != 'precinct']

print('vest sum\t\t rdh sum\tnot equal')
print('-----------------------------------------------------')
for v, m in zip(vest_cols, medsl_cols):
    if vest_shp[v].sum() != int(az_elections_pivot[m].sum()):
        print(v, vest_shp[v].sum(), '\t', m, int(az_elections_pivot[m].sum()), '\tY')
    else:
        print(v, vest_shp[v].sum(), '\t', m, int(az_elections_pivot[m].sum()))
# Out:
# vest sum		 rdh sum	not equal
# -----------------------------------------------------
# G16PRERTRU 1252401 	 pre_r 1252389 	Y
# G16PREDCLI 1161167 	 pre_d 1161165 	Y
# G16PRELJOH 106327 	 pre_l 106326 	Y
# G16PREGSTE 34345 	 pre_g 34344 	Y
# G16PREOWRI 50417 	 pre_w 50415 	Y
# G16USSRMCC 1359267 	 uss_r 1359258 	Y
# G16USSDKIR 1031245 	 uss_d 1031241 	Y
# G16USSGSWI 138634 	 uss_g 138631 	Y
# G16USSOWRI 17914 	 uss_w 17912 	Y

# %% [markdown]
# So the MEDSL results are tiny bit off from VEST's that they cleaned from the SOS but almost identical. Interesting that VEST has the same write-in votes as MEDSL for the USS race, even though ballotpedia and wikipedia only has it at 1.5k

# %% [markdown]
# # Joining Election Results

# %% [markdown]
# ## Join Attempt #1

# %%
az_elections_pivot.head(5)
# Out:
#      county_name  county_fips             precinct  pre_r  pre_d  pre_l  \
# 0  Apache County       4001.0            ALPINE|02    216     60     13
# 1  Apache County       4001.0  CANYON DE CHELLY|03    143   1387     72
# 2  Apache County       4001.0            CHINLE|05     93    678     38
# 3  Apache County       4001.0            CONCHO|09   1135    228     44
# 4  Apache County       4001.0        CORNFIELDS|10     33    349     16
#
#    pre_g  pre_w  uss_r  uss_d  uss_g  uss_w
# 0      2      4    196     65     22      5
# 1     32     51    188   1499     45      4
# 2     17     36    127    721     24      1
# 3     11     27    836    291    195     42
# 4      3     12     37    375      5      1

# %%
az_elections_pivot.shape
# Out:
# (1469, 12)

# %%
precincts.head(5)
# Out:
#    PCTNUM        PRECINCTNA CDE_COUNTY  G16PRERTRU  G16PREDCLI  G16PRELJOH  \
# 0  AP0002            ALPINE         AP         216          60          13
# 1  AP0003  CANYON DE CHELLY         AP         143        1387          72
# 2  AP0005            CHINLE         AP          93         678          38
# 3  AP0009            CONCHO         AP        1135         228          44
# 4  AP0011        COTTONWOOD         AP          47         589          26
#
#    G16PREGSTE  G16PREOWRI  G16USSRMCC  G16USSDKIR  G16USSGSWI  G16USSOWRI  \
# 0           2           4         196          65          22           5
# 1          32          51         188        1499          45           4
# 2          17          36         127         721          24           1
# 3          11          27         836         291         195          42
# 4          11          21          84         632          10           1
#
#                                             geometry
# 0  POLYGON ((-109.49567 33.65280, -109.49576 33.6...
# 1  POLYGON ((-109.71666 36.26151, -109.71658 36.2...
# 2  POLYGON ((-109.81183 36.27512, -109.80810 36.2...
# 3  POLYGON ((-109.53982 34.44871, -109.53928 34.4...
# 4  POLYGON ((-109.81768 36.14760, -109.81822 36.1...

# %%
precincts.shape
# Out:
# (1469, 13)

# %% [markdown]
# Add the county name column to the precincts file for joining to..

# %%
counties = {'AP': 'Apache', 'GLA': 'Gila',
'LP': 'La Paz', 'NA': 'Navajo', 'SC': 'Santa Cruz', 'GI': 'Gila',
'CH': 'Cochise', 'GM': 'Graham', 'MC': 'Maricopa', 'PM': 'Pima', 'YA': 'Yavapai',
'CN': 'Coconino', 'GN': 'Greenlee', 'MO': 'Mohave', 'PN': 'Pinal', 'YU': 'Yuma'}

# %%
for v, k in counties.items(): 
    precincts.loc[precincts.CDE_COUNTY == v, 'county_name'] = k

# %%
precincts.head(5)
# Out:
#    PCTNUM        PRECINCTNA CDE_COUNTY  G16PRERTRU  G16PREDCLI  G16PRELJOH  \
# 0  AP0002            ALPINE         AP         216          60          13
# 1  AP0003  CANYON DE CHELLY         AP         143        1387          72
# 2  AP0005            CHINLE         AP          93         678          38
# 3  AP0009            CONCHO         AP        1135         228          44
# 4  AP0011        COTTONWOOD         AP          47         589          26
#
#    G16PREGSTE  G16PREOWRI  G16USSRMCC  G16USSDKIR  G16USSGSWI  G16USSOWRI  \
# 0           2           4         196          65          22           5
# 1          32          51         188        1499          45           4
# 2          17          36         127         721          24           1
# 3          11          27         836         291         195          42
# 4          11          21          84         632          10           1
#
#                                             geometry county_name
# 0  POLYGON ((-109.49567 33.65280, -109.49576 33.6...      Apache
# 1  POLYGON ((-109.71666 36.26151, -109.71658 36.2...      Apache
# 2  POLYGON ((-109.81183 36.27512, -109.80810 36.2...      Apache
# 3  POLYGON ((-109.53982 34.44871, -109.53928 34.4...      Apache
# 4  POLYGON ((-109.81768 36.14760, -109.81822 36.1...      Apache

# %% [markdown]
# Split the precinct name from the precinct code by '|' in the MEDSL election results

# %%
az_elections_pivot[['precinct_name','precinct_code']] = az_elections_pivot['precinct'].str.split('|', expand = True)

# %%
az_elections_pivot.sample(20)
# Out:
#             county_name  county_fips               precinct  pre_r  pre_d  \
# 1115        Pima County       4019.0                    110     69    829
# 1422     Yavapai County       4025.0            243 - BURRO   4056   1540
# 1460        Yuma County       4027.0                     41    804    628
# 134     Coconino County       4005.0         Kaibab West 66    261     82
# 364     Maricopa County       4013.0             0121 COMET   1287    916
# 831     Maricopa County       4013.0          0588 SKY HAWK    761    392
# 341     Maricopa County       4013.0        0098 CHALLENGER    330    874
# 64       Cochise County       4003.0            Pomerene|21    528    216
# 899     Maricopa County       4013.0            0656 TUCKEY    185    480
# 37        Apache County       4001.0          SWEETWATER|76     61    228
# 587     Maricopa County       4013.0          0344 LAKEVIEW    654    381
# 1284       Pinal County       4021.0  CASA GRANDE S CENTRAL    613    553
# 1378  Santa Cruz County       4023.0             Sonoita 15    425    245
# 1264       Pinal County       4021.0          APACHE JCT NW    593    322
# 33        Apache County       4001.0       SPRINGERVILLE|70    521    145
# 740     Maricopa County       4013.0         0497 POINCIANA   1261    560
# 1419     Yavapai County       4025.0             240 - CARS    466    106
# 691     Maricopa County       4013.0             0448 OLNEY    540    930
# 949     Maricopa County       4013.0            0706 WIGWAM   2808   2222
# 653     Maricopa County       4013.0             0410 METRO    453    621
#
#       pre_l  pre_g  pre_w  uss_r  uss_d  uss_g  uss_w          precinct_name  \
# 1115     15     24     16    192    674     44      6                    110
# 1422    236     51    110   3851   1475    414     75            243 - BURRO
# 1460     60     23     30    919    483     54     17                     41
# 134      11      3      7    230     89     37      4         Kaibab West 66
# 364      97     41     42   1321    796    204     19             0121 COMET
# 831      12      2     10    739    374     37      6          0588 SKY HAWK
# 341      55     28     27    472    729     84      4        0098 CHALLENGER
# 64       31     15     11    451    268     49     11               Pomerene
# 899      27     20     16    282    382     53      1            0656 TUCKEY
# 37       36      7      3     88    243      8      0             SWEETWATER
# 587      26      7     13    617    384     69     10          0344 LAKEVIEW
# 1284     58     17     25    637    542     71      6  CASA GRANDE S CENTRAL
# 1378     20      8      9    377    254     32     21             Sonoita 15
# 1264     41     16      9    545    314     95      3          APACHE JCT NW
# 33       28      5      4    472    166     48      6          SPRINGERVILLE
# 740      71     13     66   1406    429     93     11         0497 POINCIANA
# 1419     15      8      4    360    138     64      5             240 - CARS
# 691      65     19     20    635    823     77     12             0448 OLNEY
# 949     248     57    119   3275   1834    215     19            0706 WIGWAM
# 653      70     20     18    503    551     76     13             0410 METRO
#
#      precinct_code
# 1115          None
# 1422          None
# 1460          None
# 134           None
# 364           None
# 831           None
# 341           None
# 64              21
# 899           None
# 37              76
# 587           None
# 1284          None
# 1378          None
# 1264          None
# 33              70
# 740           None
# 1419          None
# 691           None
# 949           None
# 653           None

# %% [markdown]
# Looks like this is only needed for Apache County, so we'll deal with it later

# %% [markdown]
# Remove 'County' from county_name in election results

# %%
az_elections_pivot['county'] = az_elections_pivot['county_name'].str.replace(' County','')

# %%
az_elections_pivot.sample(5)
# Out:
#           county_name  county_fips      precinct  pre_r  pre_d  pre_l  pre_g  \
# 1072      Pima County       4019.0           067    450   1117     78     50
# 344   Maricopa County       4013.0   0101 CHENEY   1573    892     62     12
# 212     Graham County       4009.0  Klondyke #12     28     15      1      0
# 1158      Pima County       4019.0           153    717   1586     84     46
# 143   Coconino County       4005.0  Page East 73    433    187     37     15
#
#       pre_w  uss_r  uss_d  uss_g  uss_w precinct_name precinct_code    county
# 1072     33    537   1023    112      5           067          None      Pima
# 344      32   1863    617     40     12   0101 CHENEY          None  Maricopa
# 212       0     19     21      2      0  Klondyke #12          None    Graham
# 1158     45    917   1407     95     17           153          None      Pima
# 143      32    434    216     42      3  Page East 73          None  Coconino

# %%
df_joined = precincts.merge(az_elections_pivot, how = 'outer'
                            , left_on = ['county_name','PRECINCTNA'], right_on = ['county','precinct']
                            , indicator = True)

# %%
df_joined.groupby('_merge').count()
# Out:
#             PCTNUM  PRECINCTNA  CDE_COUNTY  G16PRERTRU  G16PREDCLI  \
# _merge
# left_only     1351        1351        1351        1351        1351
# right_only       0           0           0           0           0
# both           118         118         118         118         118
#
#             G16PRELJOH  G16PREGSTE  G16PREOWRI  G16USSRMCC  G16USSDKIR  ...  \
# _merge                                                                  ...
# left_only         1351        1351        1351        1351        1351  ...
# right_only           0           0           0           0           0  ...
# both               118         118         118         118         118  ...
#
#             pre_l  pre_g  pre_w  uss_r  uss_d  uss_g  uss_w  precinct_name  \
# _merge
# left_only       0      0      0      0      0      0      0              0
# right_only   1351   1351   1351   1351   1351   1351   1351           1351
# both          118    118    118    118    118    118    118            118
#
#             precinct_code  county
# _merge
# left_only               0       0
# right_only             93    1351
# both                    0     118
#
# [3 rows x 29 columns]

# %% [markdown]
# ## Fuzzy String Matching

# %% [markdown]
# Test out using a fuzzy string match, because it looks like precinct names are similar but have numbers or things added.

# %%
# to install library in anaconda: conda install -c conda-forge fuzzywuzzy

from fuzzywuzzy import fuzz
from fuzzywuzzy import process

def fuzzy_merge(df_1, df_2, key1, key2, threshold, limit=1):
    """
    :param df_1: the left table to join
    :param df_2: the right table to join
    :param key1: key column of the left table
    :param key2: key column of the right table
    :param threshold: how close the matches should be to return a match, based on Levenshtein distance
    :param limit: the amount of matches that will get returned, these are sorted high to low
    :return: dataframe with boths keys and matches
    """
    s = df_2[key2].tolist()

    m = df_1[key1].apply(lambda x: process.extract(x, s, limit=limit))    
    df_1['matches'] = m

    m2 = df_1['matches'].apply(lambda x: ', '.join([i[0] for i in x if i[1] >= threshold]))
    df_1['matches'] = m2

    return df_1

# %%
precincts['county_precinct'] = precincts['county_name'] + ' ' + precincts['PRECINCTNA']
az_elections_pivot['county_precinct'] = az_elections_pivot['county'] + ' ' + az_elections_pivot['precinct']

# %%
fuzzy_merge(precincts, az_elections_pivot, 'county_precinct', 'county_precinct', threshold=90)
# Out:
#       PCTNUM        PRECINCTNA CDE_COUNTY  G16PRERTRU  G16PREDCLI  G16PRELJOH  \
# 0     AP0002            ALPINE         AP         216          60          13
# 1     AP0003  CANYON DE CHELLY         AP         143        1387          72
# 2     AP0005            CHINLE         AP          93         678          38
# 3     AP0009            CONCHO         AP        1135         228          44
# 4     AP0011        COTTONWOOD         AP          47         589          26
# ...      ...               ...        ...         ...         ...         ...
# 1464  YU0014           Yuma 14         YU         186         142          15
# 1465  YU0024           Yuma 24         YU        2517         855         105
# 1466  YU0016           Yuma 16         YU         624         488          57
# 1467  LP0056            WENDEN         LP          85          23           4
# 1468  AP0048        PUERCO E/W         AP         223         478          32
#
#       G16PREGSTE  G16PREOWRI  G16USSRMCC  G16USSDKIR  G16USSGSWI  G16USSOWRI  \
# 0              2           4         196          65          22           5
# 1             32          51         188        1499          45           4
# 2             17          36         127         721          24           1
# 3             11          27         836         291         195          42
# 4             11          21          84         632          10           1
# ...          ...         ...         ...         ...         ...         ...
# 1464          13           3         206         100          27           3
# 1465          21          36        2158         883         256          34
# 1466          13          17         658         401          63          10
# 1467           0           4          74          25          13           0
# 1468          20          35         184         556          51           3
#
#                                                geometry county_name  \
# 0     POLYGON ((-109.49567 33.65280, -109.49576 33.6...      Apache
# 1     POLYGON ((-109.71666 36.26151, -109.71658 36.2...      Apache
# 2     POLYGON ((-109.81183 36.27512, -109.80810 36.2...      Apache
# 3     POLYGON ((-109.53982 34.44871, -109.53928 34.4...      Apache
# 4     POLYGON ((-109.81768 36.14760, -109.81822 36.1...      Apache
# ...                                                 ...         ...
# 1464  POLYGON ((-114.59885 32.68006, -114.59941 32.6...        Yuma
# 1465  POLYGON ((-114.36686 32.62695, -114.40973 32.6...        Yuma
# 1466  POLYGON ((-114.63288 32.63709, -114.63393 32.6...        Yuma
# 1467  POLYGON ((-113.33383 33.90172, -113.33383 33.9...      La Paz
# 1468  POLYGON ((-109.68663 35.16998, -109.68659 35.1...      Apache
#
#               county_precinct                     matches
# 0               Apache ALPINE            Apache ALPINE|02
# 1     Apache CANYON DE CHELLY  Apache CANYON DE CHELLY|03
# 2               Apache CHINLE            Apache CHINLE|05
# 3               Apache CONCHO            Apache CONCHO|09
# 4           Apache COTTONWOOD        Apache COTTONWOOD|11
# ...                       ...                         ...
# 1464             Yuma Yuma 14                      Yuma 1
# 1465             Yuma Yuma 24                      Yuma 2
# 1466             Yuma Yuma 16                      Yuma 1
# 1467            La Paz WENDEN           La Paz 056 WENDEN
# 1468        Apache PUERCO E/W
#
# [1469 rows x 16 columns]

# %% [markdown]
# Taking a look at the fuzzy results... actually looks pretty good

# %%
precincts.sample(5)
# Out:
#       PCTNUM  PRECINCTNA CDE_COUNTY  G16PRERTRU  G16PREDCLI  G16PRELJOH  \
# 1302  PM0202    PIMA 202         PM        1280        1054         114
# 1275  PM0163    PIMA 163         PM         698         946          60
# 643   MC0668      VELERO         MC         471         511          68
# 916   MC0454        ORME         MC        1220        2317         167
# 38    AP0086  WIDE RUINS         AP          37         335          19
#
#       G16PREGSTE  G16PREOWRI  G16USSRMCC  G16USSDKIR  G16USSGSWI  G16USSOWRI  \
# 1302          31          65        1391         978         105          19
# 1275          14          28         899         768          46           7
# 643           10          19         563         435          48          10
# 916           61          50        1549        2022         177          14
# 38             5           9          39         366           7           2
#
#                                                geometry county_name  \
# 1302  POLYGON ((-111.01279 32.38797, -111.01278 32.3...        Pima
# 1275  POLYGON ((-110.84439 32.30887, -110.84736 32.3...        Pima
# 643   POLYGON ((-111.81565 33.29174, -111.81843 33.2...    Maricopa
# 916   POLYGON ((-112.28971 33.43550, -112.28982 33.4...    Maricopa
# 38    POLYGON ((-109.63337 35.17354, -109.63338 35.1...      Apache
#
#         county_precinct               matches
# 1302      Pima PIMA 202              Pima 202
# 1275      Pima PIMA 163              Pima 163
# 643     Maricopa VELERO  Maricopa 0668 VELERO
# 916       Maricopa ORME    Maricopa 0454 ORME
# 38    Apache WIDE RUINS  Apache WIDE RUINS|86

# %% [markdown]
# ## Join Attempt #2

# %% [markdown]
# Try to join again, using the fuzzy matches

# %%
df_joined = precincts.merge(az_elections_pivot, how = 'outer'
                            , left_on = ['county_name','matches'], right_on = ['county','county_precinct']
                            , indicator = True)

# %%
df_joined.groupby('_merge').count()
# Out:
#             PCTNUM  PRECINCTNA  CDE_COUNTY  G16PRERTRU  G16PREDCLI  \
# _merge
# left_only      135         135         135         135         135
# right_only       0           0           0           0           0
# both          1334        1334        1334        1334        1334
#
#             G16PRELJOH  G16PREGSTE  G16PREOWRI  G16USSRMCC  G16USSDKIR  ...  \
# _merge                                                                  ...
# left_only          135         135         135         135         135  ...
# right_only           0           0           0           0           0  ...
# both              1334        1334        1334        1334        1334  ...
#
#             pre_g  pre_w  uss_r  uss_d  uss_g  uss_w  precinct_name  \
# _merge
# left_only       0      0      0      0      0      0              0
# right_only    167    167    167    167    167    167            167
# both         1334   1334   1334   1334   1334   1334           1334
#
#             precinct_code  county  county_precinct_y
# _merge
# left_only               0       0                  0
# right_only              1     167                167
# both                   92    1334               1334
#
# [3 rows x 32 columns]

# %% [markdown]
# See what did and different match

# %%
df_joined.columns
# Out:
# Index(['PCTNUM', 'PRECINCTNA', 'CDE_COUNTY', 'G16PRERTRU', 'G16PREDCLI',
#        'G16PRELJOH', 'G16PREGSTE', 'G16PREOWRI', 'G16USSRMCC', 'G16USSDKIR',
#        'G16USSGSWI', 'G16USSOWRI', 'geometry', 'county_name_x',
#        'county_precinct_x', 'matches', 'county_name_y', 'county_fips',
#        'precinct', 'pre_r', 'pre_d', 'pre_l', 'pre_g', 'pre_w', 'uss_r',
#        'uss_d', 'uss_g', 'uss_w', 'precinct_name', 'precinct_code', 'county',
#        'county_precinct_y', '_merge'],
#       dtype='object')

# %%
df_joined.loc[df_joined['_merge'] == 'left_only'].groupby(['county_name_x']).count()
# Out:
#                PCTNUM  PRECINCTNA  CDE_COUNTY  G16PRERTRU  G16PREDCLI  \
# county_name_x
# Apache              1           1           1           1           1
# Gila                2           2           2           2           2
# Graham              1           1           1           1           1
# La Paz              3           3           3           3           3
# Maricopa            1           1           1           1           1
# Pima               99          99          99          99          99
# Yavapai            19          19          19          19          19
# Yuma                9           9           9           9           9
#
#                G16PRELJOH  G16PREGSTE  G16PREOWRI  G16USSRMCC  G16USSDKIR  \
# county_name_x
# Apache                  1           1           1           1           1
# Gila                    2           2           2           2           2
# Graham                  1           1           1           1           1
# La Paz                  3           3           3           3           3
# Maricopa                1           1           1           1           1
# Pima                   99          99          99          99          99
# Yavapai                19          19          19          19          19
# Yuma                    9           9           9           9           9
#
#                ...  pre_w  uss_r  uss_d  uss_g  uss_w  precinct_name  \
# county_name_x  ...
# Apache         ...      0      0      0      0      0              0
# Gila           ...      0      0      0      0      0              0
# Graham         ...      0      0      0      0      0              0
# La Paz         ...      0      0      0      0      0              0
# Maricopa       ...      0      0      0      0      0              0
# Pima           ...      0      0      0      0      0              0
# Yavapai        ...      0      0      0      0      0              0
# Yuma           ...      0      0      0      0      0              0
#
#                precinct_code  county  county_precinct_y  _merge
# county_name_x
# Apache                     0       0                  0       1
# Gila                       0       0                  0       2
# Graham                     0       0                  0       1
# La Paz                     0       0                  0       3
# Maricopa                   0       0                  0       1
# Pima                       0       0                  0      99
# Yavapai                    0       0                  0      19
# Yuma                       0       0                  0       9
#
# [8 rows x 32 columns]

# %%
df_joined.loc[df_joined['_merge'] == 'right_only'].groupby(['county']).count()
# Out:
#           PCTNUM  PRECINCTNA  CDE_COUNTY  G16PRERTRU  G16PREDCLI  G16PRELJOH  \
# county
# Apache         0           0           0           0           0           0
# Gila           0           0           0           0           0           0
# Graham         0           0           0           0           0           0
# La Paz         0           0           0           0           0           0
# Maricopa       0           0           0           0           0           0
# Pima           0           0           0           0           0           0
# Yavapai        0           0           0           0           0           0
# Yuma           0           0           0           0           0           0
#
#           G16PREGSTE  G16PREOWRI  G16USSRMCC  G16USSDKIR  ...  pre_g  pre_w  \
# county                                                    ...
# Apache             0           0           0           0  ...      1      1
# Gila               0           0           0           0  ...      2      2
# Graham             0           0           0           0  ...      5      5
# La Paz             0           0           0           0  ...      3      3
# Maricopa           0           0           0           0  ...      2      2
# Pima               0           0           0           0  ...     99     99
# Yavapai            0           0           0           0  ...     19     19
# Yuma               0           0           0           0  ...     36     36
#
#           uss_r  uss_d  uss_g  uss_w  precinct_name  precinct_code  \
# county
# Apache        1      1      1      1              1              1
# Gila          2      2      2      2              2              0
# Graham        5      5      5      5              5              0
# La Paz        3      3      3      3              3              0
# Maricopa      2      2      2      2              2              0
# Pima         99     99     99     99             99              0
# Yavapai      19     19     19     19             19              0
# Yuma         36     36     36     36             36              0
#
#           county_precinct_y  _merge
# county
# Apache                    1       1
# Gila                      2       2
# Graham                    5       5
# La Paz                    3       3
# Maricopa                  2       2
# Pima                     99      99
# Yavapai                  19      19
# Yuma                     36      36
#
# [8 rows x 32 columns]

# %% [markdown]
# ## County Specific Fixes

# %% [markdown]
# ### Apache

# %%
df_joined.loc[(df_joined._merge != 'both') & \
              ((df_joined.county_name_x == 'Apache') | (df_joined.county == 'Apache'))].sample(2)
# Out:
#       PCTNUM  PRECINCTNA CDE_COUNTY  G16PRERTRU  G16PREDCLI  G16PRELJOH  \
# 1468  AP0048  PUERCO E/W         AP       223.0       478.0        32.0
# 1469     NaN         NaN        NaN         NaN         NaN         NaN
#
#       G16PREGSTE  G16PREOWRI  G16USSRMCC  G16USSDKIR  ...  pre_w  uss_r  \
# 1468        20.0        35.0       184.0       556.0  ...    NaN    NaN
# 1469         NaN         NaN         NaN         NaN  ...   35.0  184.0
#
#       uss_d uss_g uss_w                precinct_name precinct_code  county  \
# 1468    NaN   NaN   NaN                          NaN           NaN     NaN
# 1469  556.0  51.0   3.0  PUERCO EAST & 49 PUERCO WES            48  Apache
#
#                           county_precinct_y      _merge
# 1468                                    NaN   left_only
# 1469  Apache PUERCO EAST & 49 PUERCO WES|48  right_only
#
# [2 rows x 33 columns]

# %%
precincts.loc[(precincts.county_name == 'Apache') & (precincts.PRECINCTNA == 'PUERCO E/W'), 'matches'] = 'Apache PUERCO EAST & 49 PUERCO WES|48'

# %% [markdown]
# ### Gila

# %%
df_joined.loc[(df_joined._merge != 'both') & \
              ((df_joined.county_name_x == 'Gila') | (df_joined.county == 'Gila'))]
# Out:
#       PCTNUM PRECINCTNA CDE_COUNTY  G16PRERTRU  G16PREDCLI  G16PRELJOH  \
# 111   GI0310   P/S EAST         GI       334.0        94.0        14.0
# 112   GI0315   P/S WEST         GI       932.0       323.0        47.0
# 1470     NaN        NaN        NaN         NaN         NaN         NaN
# 1471     NaN        NaN        NaN         NaN         NaN         NaN
#
#       G16PREGSTE  G16PREOWRI  G16USSRMCC  G16USSDKIR  ...  pre_w  uss_r  \
# 111          5.0         6.0       291.0        98.0  ...    NaN    NaN
# 112         13.0        17.0       830.0       320.0  ...    NaN    NaN
# 1470         NaN         NaN         NaN         NaN  ...    6.0  291.0
# 1471         NaN         NaN         NaN         NaN  ...   17.0  830.0
#
#       uss_d  uss_g uss_w         precinct_name precinct_code  county  \
# 111     NaN    NaN   NaN                   NaN           NaN     NaN
# 112     NaN    NaN   NaN                   NaN           NaN     NaN
# 1470   98.0   32.0   7.0  Pine-Strawberry East          None    Gila
# 1471  320.0  103.0  14.0  Pine-Strawberry West          None    Gila
#
#               county_precinct_y      _merge
# 111                         NaN   left_only
# 112                         NaN   left_only
# 1470  Gila Pine-Strawberry East  right_only
# 1471  Gila Pine-Strawberry West  right_only
#
# [4 rows x 33 columns]

# %%
precincts.loc[(precincts.county_name == 'Gila') & (precincts.PRECINCTNA == 'P/S WEST'), 'matches'] = 'Gila Pine-Strawberry West'
precincts.loc[(precincts.county_name == 'Gila') & (precincts.PRECINCTNA == 'P/S EAST'), 'matches'] = 'Gila Pine-Strawberry East'

# %% [markdown]
# ### Graham

# %%
df_joined.loc[(df_joined._merge != 'both') & \
              ((df_joined.county_name_x == 'Graham') | (df_joined.county == 'Graham'))]
# Out:
#       PCTNUM   PRECINCTNA CDE_COUNTY  G16PRERTRU  G16PREDCLI  G16PRELJOH  \
# 119   GM0010  FORT THOMAS         GM       159.0        22.0         5.0
# 1472     NaN          NaN        NaN         NaN         NaN         NaN
# 1473     NaN          NaN        NaN         NaN         NaN         NaN
# 1474     NaN          NaN        NaN         NaN         NaN         NaN
# 1475     NaN          NaN        NaN         NaN         NaN         NaN
# 1476     NaN          NaN        NaN         NaN         NaN         NaN
#
#       G16PREGSTE  G16PREOWRI  G16USSRMCC  G16USSDKIR  ...  pre_w  uss_r  \
# 119          2.0         1.0       131.0        26.0  ...    NaN    NaN
# 1472         NaN         NaN         NaN         NaN  ...    1.0  131.0
# 1473         NaN         NaN         NaN         NaN  ...   25.0  590.0
# 1474         NaN         NaN         NaN         NaN  ...   17.0  558.0
# 1475         NaN         NaN         NaN         NaN  ...    6.0  319.0
# 1476         NaN         NaN         NaN         NaN  ...   50.0  837.0
#
#       uss_d uss_g uss_w  precinct_name precinct_code  county  \
# 119     NaN   NaN   NaN            NaN           NaN     NaN
# 1472   26.0  24.0   3.0  Ft Thomas #10          None  Graham
# 1473  246.0  54.0   6.0      Layton #5          None  Graham
# 1474  303.0  51.0  11.0     Safford #2          None  Graham
# 1475  113.0  28.0   4.0     Safford #3          None  Graham
# 1476  247.0  78.0   8.0    Thatcher #7          None  Graham
#
#          county_precinct_y      _merge
# 119                    NaN   left_only
# 1472  Graham Ft Thomas #10  right_only
# 1473      Graham Layton #5  right_only
# 1474     Graham Safford #2  right_only
# 1475     Graham Safford #3  right_only
# 1476    Graham Thatcher #7  right_only
#
# [6 rows x 33 columns]

# %% [markdown]
# See if there are the same number of precincts in Graham in the election results and the shapefile

# %%
precincts[precincts.county_name == 'Graham'].shape
# Out:
# (22, 16)

# %%
az_elections_pivot[az_elections_pivot.county == 'Graham'].shape
# Out:
# (22, 16)

# %%
df_joined.loc[((df_joined.county_name_x == 'Graham') | (df_joined.county == 'Graham'))][['PCTNUM',
                    'PRECINCTNA','county_name_x','G16PRERTRU','precinct','county','pre_r']]
# Out:
#       PCTNUM     PRECINCTNA county_name_x  G16PRERTRU           precinct  \
# 114   GM0006       THATCHER        Graham       451.0        Thatcher #6
# 115   GM0007       THATCHER        Graham       847.0        Thatcher #6
# 118   GM0009           PIMA        Graham      1239.0            Pima #9
# 119   GM0010    FORT THOMAS        Graham       159.0                NaN
# 120   GM0011          BYLAS        Graham        42.0          Bylas #11
# 121   GM0012       KLONDYKE        Graham        28.0       Klondyke #12
# 122   GM0013         BONITA        Graham       105.0         Bonita #13
# 124   GM0016        PERIDOT        Graham        40.0        Peridot #16
# 125   GM0017         CACTUS        Graham       109.0         Cactus #17
# 440   GM0001        SOLOMON        Graham       428.0         Solomon #1
# 441   GM0002        SAFFORD        Graham       620.0        Safford #15
# 442   GM0003        SAFFORD        Graham       565.0        Safford #15
# 443   GM0015        SAFFORD        Graham       334.0        Safford #15
# 491   GM0018        JACKSON        Graham       635.0        Jackson #18
# 1028  GM0004         LAYTON        Graham       207.0          Layton #4
# 1029  GM0005         LAYTON        Graham       587.0          Layton #4
# 1031  GM0008        CENTRAL        Graham       374.0         Central #8
# 1033  GM0014    THUNDERBIRD        Graham       186.0    Thunderbird #14
# 1035  GM0021  QUATRO CERROS        Graham        52.0  Quatro Cerros #21
# 1036  GM0019   DESERT HILLS        Graham       606.0   Desert Hills #19
# 1037  GM0022     GILA RIVER        Graham        11.0     Gila River #22
# 1038  GM0020        ARTESIA        Graham       400.0        Artesia #20
# 1472     NaN            NaN           NaN         NaN      Ft Thomas #10
# 1473     NaN            NaN           NaN         NaN          Layton #5
# 1474     NaN            NaN           NaN         NaN         Safford #2
# 1475     NaN            NaN           NaN         NaN         Safford #3
# 1476     NaN            NaN           NaN         NaN        Thatcher #7
#
#       county   pre_r
# 114   Graham   451.0
# 115   Graham   451.0
# 118   Graham  1239.0
# 119      NaN     NaN
# 120   Graham    42.0
# 121   Graham    28.0
# 122   Graham   105.0
# 124   Graham    40.0
# 125   Graham   109.0
# 440   Graham   428.0
# 441   Graham   620.0
# 442   Graham   620.0
# 443   Graham   620.0
# 491   Graham   635.0
# 1028  Graham   207.0
# 1029  Graham   207.0
# 1031  Graham   374.0
# 1033  Graham   186.0
# 1035  Graham    52.0
# 1036  Graham   606.0
# 1037  Graham    11.0
# 1038  Graham   400.0
# 1472  Graham   159.0
# 1473  Graham   587.0
# 1474  Graham   565.0
# 1475  Graham   334.0
# 1476  Graham   847.0

# %% [markdown]
# Pulled the above to a sheet and lined them up, exported the following data dictionary:

# %%
graham_dict = {'GM0006':'Thatcher #6','GM0007':'Thatcher #7','GM0009':'Pima #9','GM0010':'Ft Thomas #10',
               'GM0011':'Bylas #11','GM0012':'Klondyke #12','GM0013':'Bonita #13','GM0016':'Peridot #16',
               'GM0017':'Cactus #17','GM0001':'Solomon #1','GM0002':'Safford #2','GM0003':'Safford #3',
               'GM0015':'Safford #15','GM0018':'Jackson #18','GM0004':'Layton #4','GM0005':'Layton #5',
               'GM0008':'Central #8','GM0014':'Thunderbird #14','GM0021':'Quatro Cerros #21',
               'GM0019':'Desert Hills #19','GM0022':'Gila River #22','GM0020':'Artesia #20'}

# %%
for key in graham_dict:
    precincts.loc[(precincts.county_name == 'Graham') & (precincts.PCTNUM == key), 'matches'] = 'Graham ' + graham_dict[key]

# %% [markdown]
# ### La Paz

# %%
df_joined.loc[(df_joined._merge != 'both') & \
              ((df_joined.county_name_x == 'La Paz') | (df_joined.county == 'La Paz'))]
# Out:
#       PCTNUM    PRECINCTNA CDE_COUNTY  G16PRERTRU  G16PREDCLI  G16PRELJOH  \
# 557   LP0064  QUARTZSITE 3         LP       273.0        66.0         9.0
# 558   LP0051      PARKER 1         LP       951.0       702.0        85.0
# 559   LP0058  QUARTZSITE 2         LP       551.0       149.0        32.0
# 1477     NaN           NaN        NaN         NaN         NaN         NaN
# 1478     NaN           NaN        NaN         NaN         NaN         NaN
# 1479     NaN           NaN        NaN         NaN         NaN         NaN
#
#       G16PREGSTE  G16PREOWRI  G16USSRMCC  G16USSDKIR  ...  pre_w  uss_r  \
# 557          2.0         8.0       248.0        78.0  ...    NaN    NaN
# 558         43.0        35.0       996.0       660.0  ...    NaN    NaN
# 559         10.0         7.0       447.0       196.0  ...    NaN    NaN
# 1477         NaN         NaN         NaN         NaN  ...   35.0  996.0
# 1478         NaN         NaN         NaN         NaN  ...    7.0  447.0
# 1479         NaN         NaN         NaN         NaN  ...    8.0  248.0
#
#       uss_d  uss_g uss_w         precinct_name precinct_code  county  \
# 557     NaN    NaN   NaN                   NaN           NaN     NaN
# 558     NaN    NaN   NaN                   NaN           NaN     NaN
# 559     NaN    NaN   NaN                   NaN           NaN     NaN
# 1477  660.0  117.0  17.0            051 PARKER          None  La Paz
# 1478  196.0   71.0  15.0    058 QUARTZSITE TWO          None  La Paz
# 1479   78.0   22.0   3.0  064 QUARTZSITE THREE          None  La Paz
#
#                 county_precinct_y      _merge
# 557                           NaN   left_only
# 558                           NaN   left_only
# 559                           NaN   left_only
# 1477            La Paz 051 PARKER  right_only
# 1478    La Paz 058 QUARTZSITE TWO  right_only
# 1479  La Paz 064 QUARTZSITE THREE  right_only
#
# [6 rows x 33 columns]

# %%
precincts.loc[(precincts.county_name == 'La Paz') & (precincts.PRECINCTNA == 'PARKER 1'), 'matches'] = 'La Paz 051 PARKER'
precincts.loc[(precincts.county_name == 'La Paz') & (precincts.PRECINCTNA == 'QUARTZSITE 2'), 'matches'] = 'La Paz 058 QUARTZSITE TWO'
precincts.loc[(precincts.county_name == 'La Paz') & (precincts.PRECINCTNA == 'QUARTZSITE 3'), 'matches'] = 'La Paz 064 QUARTZSITE THREE'

# %% [markdown]
# ### Maricopa

# %%
df_joined.loc[(df_joined._merge != 'both') & \
              ((df_joined.county_name_x == 'Maricopa') | (df_joined.county == 'Maricopa'))]
# Out:
#       PCTNUM     PRECINCTNA CDE_COUNTY  G16PRERTRU  G16PREDCLI  G16PRELJOH  \
# 1209  MC0548  TOWNE MEADOWS         MC      1131.0       717.0       122.0
# 1480     NaN            NaN        NaN         NaN         NaN         NaN
# 1481     NaN            NaN        NaN         NaN         NaN         NaN
#
#       G16PREGSTE  G16PREOWRI  G16USSRMCC  G16USSDKIR  ...  pre_w   uss_r  \
# 1209        26.0        74.0      1300.0       601.0  ...    NaN     NaN
# 1480         NaN         NaN         NaN         NaN  ...   23.0  1124.0
# 1481         NaN         NaN         NaN         NaN  ...   74.0  1300.0
#
#       uss_d  uss_g uss_w      precinct_name precinct_code    county  \
# 1209    NaN    NaN   NaN                NaN           NaN       NaN
# 1480  970.0  120.0  10.0      0389 MARICOPA          None  Maricopa
# 1481  601.0  101.0  14.0  0548 TOWN MEADOWS          None  Maricopa
#
#                county_precinct_y      _merge
# 1209                         NaN   left_only
# 1480      Maricopa 0389 MARICOPA  right_only
# 1481  Maricopa 0548 TOWN MEADOWS  right_only
#
# [3 rows x 33 columns]

# %%
df_joined.loc[((df_joined.county_name_x == 'Maricopa') | (df_joined.county == 'Maricopa')) & (df_joined.PCTNUM == 'MC0389')][['PCTNUM',
                    'PRECINCTNA','county_name_x','G16PRERTRU','precinct','county','pre_r']]
# Out:
#       PCTNUM PRECINCTNA county_name_x  G16PRERTRU     precinct    county  \
# 1040  MC0389   MARICOPA      Maricopa       928.0  0001 ACACIA  Maricopa
#
#        pre_r
# 1040  1156.0

# %%
df_joined.loc[((df_joined.county_name_x == 'Maricopa') | (df_joined.county == 'Maricopa')) & (df_joined.PCTNUM == 'MC0001')][['PCTNUM',
                    'PRECINCTNA','county_name_x','G16PRERTRU','precinct','county','pre_r']]
# Out:
#       PCTNUM PRECINCTNA county_name_x  G16PRERTRU     precinct    county  \
# 1039  MC0001     ACACIA      Maricopa      1156.0  0001 ACACIA  Maricopa
#
#        pre_r
# 1039  1156.0

# %%
precincts.loc[(precincts.county_name == 'Maricopa') & (precincts.PCTNUM == 'MC0548'), 'matches'] = 'Maricopa 0548 TOWN MEADOWS'
precincts.loc[(precincts.county_name == 'Maricopa') & (precincts.PCTNUM == 'MC0389'), 'matches'] = 'Maricopa 0389 MARICOPA'

# %% [markdown]
# ### Pima

# %%
df_joined.loc[(df_joined._merge != 'both') & \
              ((df_joined.county_name_x == 'Pima') | (df_joined.county == 'Pima'))]
# Out:
#       PCTNUM PRECINCTNA CDE_COUNTY  G16PRERTRU  G16PREDCLI  G16PRELJOH  \
# 274   PM0004     PIMA 4         PM        59.0       597.0        17.0
# 275   PM0010    PIMA 10         PM       825.0       749.0        36.0
# 276   PM0012    PIMA 12         PM      1833.0      1688.0       115.0
# 277   PM0022    PIMA 22         PM       596.0      1591.0        66.0
# 278   PM0027    Pima 27         PM         0.0         0.0         0.0
# ...      ...        ...        ...         ...         ...         ...
# 1576     NaN        NaN        NaN         NaN         NaN         NaN
# 1577     NaN        NaN        NaN         NaN         NaN         NaN
# 1578     NaN        NaN        NaN         NaN         NaN         NaN
# 1579     NaN        NaN        NaN         NaN         NaN         NaN
# 1580     NaN        NaN        NaN         NaN         NaN         NaN
#
#       G16PREGSTE  G16PREOWRI  G16USSRMCC  G16USSDKIR  ...  pre_w  uss_r  \
# 274         23.0         8.0       158.0       506.0  ...    NaN    NaN
# 275          5.0        23.0       804.0       696.0  ...    NaN    NaN
# 276         28.0        57.0      1965.0      1538.0  ...    NaN    NaN
# 277         30.0        28.0       758.0      1366.0  ...    NaN    NaN
# 278          0.0         0.0         0.0         0.0  ...    NaN    NaN
# ...          ...         ...         ...         ...  ...    ...    ...
# 1576         NaN         NaN         NaN         NaN  ...   27.0  632.0
# 1577         NaN         NaN         NaN         NaN  ...   31.0  614.0
# 1578         NaN         NaN         NaN         NaN  ...   18.0  449.0
# 1579         NaN         NaN         NaN         NaN  ...   37.0  620.0
# 1580         NaN         NaN         NaN         NaN  ...   25.0  620.0
#
#        uss_d  uss_g uss_w precinct_name precinct_code  county  \
# 274      NaN    NaN   NaN           NaN           NaN     NaN
# 275      NaN    NaN   NaN           NaN           NaN     NaN
# 276      NaN    NaN   NaN           NaN           NaN     NaN
# 277      NaN    NaN   NaN           NaN           NaN     NaN
# 278      NaN    NaN   NaN           NaN           NaN     NaN
# ...      ...    ...   ...           ...           ...     ...
# 1576   351.0   58.0   6.0           095          None    Pima
# 1577  1158.0   88.0   9.0           096          None    Pima
# 1578   875.0   61.0   8.0           097          None    Pima
# 1579  1173.0  125.0   3.0           098          None    Pima
# 1580  1112.0   55.0   6.0           099          None    Pima
#
#      county_precinct_y      _merge
# 274                NaN   left_only
# 275                NaN   left_only
# 276                NaN   left_only
# 277                NaN   left_only
# 278                NaN   left_only
# ...                ...         ...
# 1576          Pima 095  right_only
# 1577          Pima 096  right_only
# 1578          Pima 097  right_only
# 1579          Pima 098  right_only
# 1580          Pima 099  right_only
#
# [198 rows x 33 columns]

# %%
df_joined.loc[((df_joined.county_name_x == 'Pima') | (df_joined.county == 'Pima'))][['PCTNUM',
                    'PRECINCTNA','county_name_x','G16PRERTRU','matches','precinct','county','county_precinct_y','pre_r']]
# Out:
#       PCTNUM PRECINCTNA county_name_x  G16PRERTRU matches precinct county  \
# 274   PM0004     PIMA 4          Pima        59.0              NaN    NaN
# 275   PM0010    PIMA 10          Pima       825.0              NaN    NaN
# 276   PM0012    PIMA 12          Pima      1833.0              NaN    NaN
# 277   PM0022    PIMA 22          Pima       596.0              NaN    NaN
# 278   PM0027    Pima 27          Pima         0.0              NaN    NaN
# ...      ...        ...           ...         ...     ...      ...    ...
# 1576     NaN        NaN           NaN         NaN     NaN      095   Pima
# 1577     NaN        NaN           NaN         NaN     NaN      096   Pima
# 1578     NaN        NaN           NaN         NaN     NaN      097   Pima
# 1579     NaN        NaN           NaN         NaN     NaN      098   Pima
# 1580     NaN        NaN           NaN         NaN     NaN      099   Pima
#
#      county_precinct_y  pre_r
# 274                NaN    NaN
# 275                NaN    NaN
# 276                NaN    NaN
# 277                NaN    NaN
# 278                NaN    NaN
# ...                ...    ...
# 1576          Pima 095  569.0
# 1577          Pima 096  481.0
# 1578          Pima 097  329.0
# 1579          Pima 098  508.0
# 1580          Pima 099  473.0
#
# [347 rows x 9 columns]

# %%
precincts[['part1_temp', 'part2_temp', 'part3_temp']] \
    = precincts['PRECINCTNA'].str.split(' ',2, expand = True)

# %%
precincts.loc[precincts.county_name == 'Pima'][['part1_temp', 'part2_temp', 'part3_temp']].head()
# Out:
#     part1_temp part2_temp part3_temp
# 273       PIMA          4       None
# 279       PIMA         10       None
# 280       PIMA         12       None
# 286       PIMA         22       None
# 291       Pima         27       None

# %%
precincts['matches'] = np.where(precincts['county_name'] == 'Pima', 
         precincts['county_name'] + ' ' + \
         precincts['part2_temp'].apply(lambda x: x.zfill(3) if x else x), 
         precincts['matches'])

# %%
precincts.loc[precincts.county_name == 'Pima'][['matches','part1_temp', 'part2_temp', 'part3_temp']].head()
# Out:
#       matches part1_temp part2_temp part3_temp
# 273  Pima 004       PIMA          4       None
# 279  Pima 010       PIMA         10       None
# 280  Pima 012       PIMA         12       None
# 286  Pima 022       PIMA         22       None
# 291  Pima 027       Pima         27       None

# %% [markdown]
# ### Yavapai

# %%
df_joined.loc[(df_joined._merge != 'both') & \
              ((df_joined.county_name_x == 'Yavapai') | (df_joined.county == 'Yavapai'))][['PCTNUM',
                    'PRECINCTNA','county_name_x','G16PRERTRU','matches','precinct','county','county_precinct_y','pre_r']]
# Out:
#       PCTNUM PRECINCTNA county_name_x  G16PRERTRU matches    precinct  \
# 510   YA0209       WICK       Yavapai       237.0                 NaN
# 511   YA0214       KIRK       Yavapai       344.0                 NaN
# 512   YA0217       WIND       Yavapai        57.0                 NaN
# 513   YA0218       WELL       Yavapai      1290.0                 NaN
# 514   YA0225       IRON       Yavapai      3420.0                 NaN
# 515   YA0240       CARS       Yavapai       466.0                 NaN
# 516   YA0203       FAIR       Yavapai      1992.0                 NaN
# 517   YA0204       GOLF       Yavapai      3022.0                 NaN
# 518   YA0219       FORT       Yavapai      3202.0                 NaN
# 519   YA0220        RIM       Yavapai        14.0                 NaN
# 520   YA0221       SALT       Yavapai       226.0                 NaN
# 521   YA0222        BUG       Yavapai      1823.0                 NaN
# 522   YA0229       ONYX       Yavapai      3263.0                 NaN
# 523   YA0205       MINE       Yavapai       518.0                 NaN
# 524   YA0206       HILL       Yavapai        69.0                 NaN
# 525   YA0208       YARN       Yavapai       441.0                 NaN
# 526   YA0215       BUCK       Yavapai      2437.0                 NaN
# 527   YA0227       RUBY       Yavapai      1681.0                 NaN
# 528   YA0236       CAMP       Yavapai       319.0                 NaN
# 1581     NaN        NaN           NaN         NaN     NaN  203 - FAIR
# 1582     NaN        NaN           NaN         NaN     NaN  204 - GOLF
# 1583     NaN        NaN           NaN         NaN     NaN  205 - MINE
# 1584     NaN        NaN           NaN         NaN     NaN  206 - HILL
# 1585     NaN        NaN           NaN         NaN     NaN  208 - YARN
# 1586     NaN        NaN           NaN         NaN     NaN  209 - WICK
# 1587     NaN        NaN           NaN         NaN     NaN  214 - KIRK
# 1588     NaN        NaN           NaN         NaN     NaN  215 - BUCK
# 1589     NaN        NaN           NaN         NaN     NaN  217 - WIND
# 1590     NaN        NaN           NaN         NaN     NaN  218 - WELL
# 1591     NaN        NaN           NaN         NaN     NaN  219 - FORT
# 1592     NaN        NaN           NaN         NaN     NaN   220 - RIM
# 1593     NaN        NaN           NaN         NaN     NaN  221 - SALT
# 1594     NaN        NaN           NaN         NaN     NaN   222 - BUG
# 1595     NaN        NaN           NaN         NaN     NaN  225 - IRON
# 1596     NaN        NaN           NaN         NaN     NaN  227 - RUBY
# 1597     NaN        NaN           NaN         NaN     NaN  229 - ONYX
# 1598     NaN        NaN           NaN         NaN     NaN  236 - CAMP
# 1599     NaN        NaN           NaN         NaN     NaN  240 - CARS
#
#        county   county_precinct_y   pre_r
# 510       NaN                 NaN     NaN
# 511       NaN                 NaN     NaN
# 512       NaN                 NaN     NaN
# 513       NaN                 NaN     NaN
# 514       NaN                 NaN     NaN
# 515       NaN                 NaN     NaN
# 516       NaN                 NaN     NaN
# 517       NaN                 NaN     NaN
# 518       NaN                 NaN     NaN
# 519       NaN                 NaN     NaN
# 520       NaN                 NaN     NaN
# 521       NaN                 NaN     NaN
# 522       NaN                 NaN     NaN
# 523       NaN                 NaN     NaN
# 524       NaN                 NaN     NaN
# 525       NaN                 NaN     NaN
# 526       NaN                 NaN     NaN
# 527       NaN                 NaN     NaN
# 528       NaN                 NaN     NaN
# 1581  Yavapai  Yavapai 203 - FAIR  1992.0
# 1582  Yavapai  Yavapai 204 - GOLF  3022.0
# 1583  Yavapai  Yavapai 205 - MINE   518.0
# 1584  Yavapai  Yavapai 206 - HILL    69.0
# 1585  Yavapai  Yavapai 208 - YARN   441.0
# 1586  Yavapai  Yavapai 209 - WICK   237.0
# 1587  Yavapai  Yavapai 214 - KIRK   344.0
# 1588  Yavapai  Yavapai 215 - BUCK  2437.0
# 1589  Yavapai  Yavapai 217 - WIND    57.0
# 1590  Yavapai  Yavapai 218 - WELL  1290.0
# 1591  Yavapai  Yavapai 219 - FORT  3202.0
# 1592  Yavapai   Yavapai 220 - RIM    14.0
# 1593  Yavapai  Yavapai 221 - SALT   226.0
# 1594  Yavapai   Yavapai 222 - BUG  1823.0
# 1595  Yavapai  Yavapai 225 - IRON  3420.0
# 1596  Yavapai  Yavapai 227 - RUBY  1681.0
# 1597  Yavapai  Yavapai 229 - ONYX  3263.0
# 1598  Yavapai  Yavapai 236 - CAMP   319.0
# 1599  Yavapai  Yavapai 240 - CARS   466.0

# %%
yavapai_dict = {'YA0209':'Yavapai 209 - WICK',
'YA0214':'Yavapai 214 - KIRK',
'YA0217':'Yavapai 217 - WIND',
'YA0218':'Yavapai 218 - WELL',
'YA0225':'Yavapai 225 - IRON',
'YA0240':'Yavapai 240 - CARS',
'YA0203':'Yavapai 203 - FAIR',
'YA0204':'Yavapai 204 - GOLF',
'YA0219':'Yavapai 219 - FORT',
'YA0220':'Yavapai 220 - RIM',
'YA0221':'Yavapai 221 - SALT',
'YA0222':'Yavapai 222 - BUG',
'YA0229':'Yavapai 229 - ONYX',
'YA0205':'Yavapai 205 - MINE',
'YA0206':'Yavapai 206 - HILL',
'YA0208':'Yavapai 208 - YARN',
'YA0215':'Yavapai 215 - BUCK',
'YA0227':'Yavapai 227 - RUBY',
'YA0236':'Yavapai 236 - CAMP',}

# %%
for key in yavapai_dict:
    precincts.loc[(precincts.county_name == 'Yavapai') & (precincts.PCTNUM == key), 'matches'] = yavapai_dict[key]

# %% [markdown]
# ### Yuma

# %%
df_joined.loc[ #(df_joined._merge != 'both') & \
              ((df_joined.county_name_x == 'Yuma') | (df_joined.county == 'Yuma'))][['PCTNUM',
                    'PRECINCTNA','county_name_x','G16PRERTRU','matches','precinct','county','county_precinct_y','pre_r']].sample(30)
# Out:
#       PCTNUM PRECINCTNA county_name_x  G16PRERTRU  matches precinct county  \
# 1613     NaN        NaN           NaN         NaN      NaN       25   Yuma
# 1633     NaN        NaN           NaN         NaN      NaN        7   Yuma
# 752   YU0025    Yuma 25          Yuma      1502.0   Yuma 2        2   Yuma
# 1600     NaN        NaN           NaN         NaN      NaN       10   Yuma
# 778   YU0001    Yuma 01          Yuma       174.0               NaN    NaN
# 1602     NaN        NaN           NaN         NaN      NaN       13   Yuma
# 1460  YU0011    Yuma 11          Yuma       963.0  Yuma 11       11   Yuma
# 776   YU0003    Yuma 03          Yuma       235.0               NaN    NaN
# 750   YU0020    Yuma 20          Yuma      1034.0   Yuma 2        2   Yuma
# 1609     NaN        NaN           NaN         NaN      NaN       20   Yuma
# 772   YU0031    Yuma 31          Yuma       175.0   Yuma 3        3   Yuma
# 1629     NaN        NaN           NaN         NaN      NaN       42   Yuma
# 1631     NaN        NaN           NaN         NaN      NaN        5   Yuma
# 771   YU0036    Yuma 36          Yuma       677.0   Yuma 3        3   Yuma
# 1635     NaN        NaN           NaN         NaN      NaN        9   Yuma
# 779   YU0009    Yuma 09          Yuma       994.0               NaN    NaN
# 757   YU0024    Yuma 24          Yuma      2517.0   Yuma 2        2   Yuma
# 1632     NaN        NaN           NaN         NaN      NaN        6   Yuma
# 762   YU0010    Yuma 10          Yuma      1439.0   Yuma 1        1   Yuma
# 764   YU0018    Yuma 18          Yuma       128.0   Yuma 1        1   Yuma
# 774   YU0030    Yuma 30          Yuma       125.0   Yuma 3        3   Yuma
# 1611     NaN        NaN           NaN         NaN      NaN       23   Yuma
# 1626     NaN        NaN           NaN         NaN      NaN       39   Yuma
# 1463  YU0043    Yuma 43          Yuma        14.0   Yuma 4        4   Yuma
# 1622     NaN        NaN           NaN         NaN      NaN       35   Yuma
# 1612     NaN        NaN           NaN         NaN      NaN       24   Yuma
# 758   YU0017    Yuma 17          Yuma      1297.0   Yuma 1        1   Yuma
# 755   YU0026    Yuma 26          Yuma        88.0   Yuma 2        2   Yuma
# 1625     NaN        NaN           NaN         NaN      NaN       38   Yuma
# 748   YU0044    Yuma 44          Yuma         0.0  Yuma 44       44   Yuma
#
#      county_precinct_y   pre_r
# 1613           Yuma 25  1502.0
# 1633            Yuma 7   199.0
# 752             Yuma 2   283.0
# 1600           Yuma 10  1439.0
# 778                NaN     NaN
# 1602           Yuma 13   373.0
# 1460           Yuma 11   963.0
# 776                NaN     NaN
# 750             Yuma 2   283.0
# 1609           Yuma 20  1034.0
# 772             Yuma 3   235.0
# 1629           Yuma 42   683.0
# 1631            Yuma 5   808.0
# 771             Yuma 3   235.0
# 1635            Yuma 9   994.0
# 779                NaN     NaN
# 757             Yuma 2   283.0
# 1632            Yuma 6   298.0
# 762             Yuma 1   174.0
# 764             Yuma 1   174.0
# 774             Yuma 3   235.0
# 1611           Yuma 23   985.0
# 1626           Yuma 39   711.0
# 1463            Yuma 4   806.0
# 1622           Yuma 35   658.0
# 1612           Yuma 24  2517.0
# 758             Yuma 1   174.0
# 755             Yuma 2   283.0
# 1625           Yuma 38   571.0
# 748            Yuma 44     0.0

# %%
precincts[['part1_temp', 'part2_temp', 'part3_temp']] \
    = precincts['PRECINCTNA'].str.split(' ',2, expand = True)

# %%
precincts.loc[precincts.county_name == 'Yuma'][['part1_temp', 'part2_temp', 'part3_temp']].head()
# Out:
#     part1_temp part2_temp part3_temp
# 656       Yuma         44       None
# 657       Yuma         21       None
# 658       Yuma         17       None
# 659       Yuma         20       None
# 660       Yuma         37       None

# %%
precincts['matches'] = np.where(precincts['county_name'] == 'Yuma', 
         precincts['county_name'] + ' ' + \
         precincts['part2_temp'].str.lstrip('0'), 
         precincts['matches'])

# %%
precincts.loc[precincts.county_name == 'Yuma'][['matches','part1_temp', 'part2_temp', 'part3_temp']].head()
# Out:
#      matches part1_temp part2_temp part3_temp
# 656  Yuma 44       Yuma         44       None
# 657  Yuma 21       Yuma         21       None
# 658  Yuma 17       Yuma         17       None
# 659  Yuma 20       Yuma         20       None
# 660  Yuma 37       Yuma         37       None

# %% [markdown]
# ## Join Attempt #3

# %%
df_joined = precincts.merge(az_elections_pivot, how = 'outer'
                            , left_on = ['county_name','matches'], right_on = ['county','county_precinct']
                            , indicator = True)

# %%
df_joined.groupby('_merge').count()
# Out:
#             PCTNUM  PRECINCTNA  CDE_COUNTY  G16PRERTRU  G16PREDCLI  \
# _merge
# left_only        0           0           0           0           0
# right_only       0           0           0           0           0
# both          1469        1469        1469        1469        1469
#
#             G16PRELJOH  G16PREGSTE  G16PREOWRI  G16USSRMCC  G16USSDKIR  ...  \
# _merge                                                                  ...
# left_only            0           0           0           0           0  ...
# right_only           0           0           0           0           0  ...
# both              1469        1469        1469        1469        1469  ...
#
#             pre_g  pre_w  uss_r  uss_d  uss_g  uss_w  precinct_name  \
# _merge
# left_only       0      0      0      0      0      0              0
# right_only      0      0      0      0      0      0              0
# both         1469   1469   1469   1469   1469   1469           1469
#
#             precinct_code  county  county_precinct_y
# _merge
# left_only               0       0                  0
# right_only              0       0                  0
# both                   93    1469               1469
#
# [3 rows x 35 columns]

# %% [markdown]
# Got everything to match!

# %%
df_joined.drop(columns=['_merge'], inplace = True)

# %% [markdown]
# Take a look at the string matching column to put examples in the report:

# %%
df_joined[['county_precinct_x','matches']].sample(15)
# Out:
#            county_precinct_x                     matches
# 1460            Yuma Yuma 18                     Yuma 18
# 199      Maricopa LONE BUTTE    Maricopa 0365 LONE BUTTE
# 246      Maricopa SUNNY HIGH    Maricopa 0627 SUNNY HIGH
# 472      Maricopa PEPPERWOOD    Maricopa 0483 PEPPERWOOD
# 642       Maricopa STONEGATE     Maricopa 0612 STONEGATE
# 1343            Pinal KEARNY                Pinal KEARNY
# 1310    Pinal CASA GRANDE SE        Pinal CASA GRANDE SE
# 379    Maricopa HAPPY VALLEY  Maricopa 0277 HAPPY VALLEY
# 888        Cochise TOMBSTONE        Cochise Tombstone|44
# 406       Santa Cruz Elgin 6          Santa Cruz Elgin 6
# 331   Coconino FLAGSTAFF #03        Coconino Flagstaff 3
# 1222            Pima PIMA 95                    Pima 095
# 356            Pima PIMA 216                    Pima 216
# 308       Maricopa PEAK VIEW     Maricopa 0475 PEAK VIEW
# 1132     Maricopa SWEETWATER    Maricopa 0637 SWEETWATER

# %%
df_joined.columns
# Out:
# Index(['PCTNUM', 'PRECINCTNA', 'CDE_COUNTY', 'G16PRERTRU', 'G16PREDCLI',
#        'G16PRELJOH', 'G16PREGSTE', 'G16PREOWRI', 'G16USSRMCC', 'G16USSDKIR',
#        'G16USSGSWI', 'G16USSOWRI', 'geometry', 'county_name_x',
#        'county_precinct_x', 'matches', 'part1_temp', 'part2_temp',
#        'part3_temp', 'county_name_y', 'county_fips', 'precinct', 'pre_r',
#        'pre_d', 'pre_l', 'pre_g', 'pre_w', 'uss_r', 'uss_d', 'uss_g', 'uss_w',
#        'precinct_name', 'precinct_code', 'county', 'county_precinct_y'],
#       dtype='object')

# %% [markdown]
# <a name="comparison"></a>

# %% [markdown]
# # Comparison to VEST

# %% [markdown]
# ## Join Final to VEST

# %% [markdown]
# This is somewhat duplicitous since the source file we received is the same as VEST...

# %%
vest_shp.PCTNUM.is_unique
# Out:
# True

# %%
vest_shp.shape
# Out:
# (1469, 13)

# %%
df_joined.PCTNUM.is_unique
# Out:
# True

# %%
df_joined.shape
# Out:
# (1469, 35)

# %%
vest_shp.columns
# Out:
# Index(['PCTNUM', 'PRECINCTNA', 'CDE_COUNTY', 'G16PRERTRU', 'G16PREDCLI',
#        'G16PRELJOH', 'G16PREGSTE', 'G16PREOWRI', 'G16USSRMCC', 'G16USSDKIR',
#        'G16USSGSWI', 'G16USSOWRI', 'geometry'],
#       dtype='object')

# %%
df_joined.columns
# Out:
# Index(['PCTNUM', 'PRECINCTNA', 'CDE_COUNTY', 'G16PRERTRU', 'G16PREDCLI',
#        'G16PRELJOH', 'G16PREGSTE', 'G16PREOWRI', 'G16USSRMCC', 'G16USSDKIR',
#        'G16USSGSWI', 'G16USSOWRI', 'geometry', 'county_name_x',
#        'county_precinct_x', 'matches', 'part1_temp', 'part2_temp',
#        'part3_temp', 'county_name_y', 'county_fips', 'precinct', 'pre_r',
#        'pre_d', 'pre_l', 'pre_g', 'pre_w', 'uss_r', 'uss_d', 'uss_g', 'uss_w',
#        'precinct_name', 'precinct_code', 'county', 'county_precinct_y'],
#       dtype='object')

# %%
df_joined.columns = ['PCTNUM', 'PRECINCTNA', 'CDE_COUNTY', 'G16PRERTRU_raw', 'G16PREDCLI_raw',
       'G16PRELJOH_raw', 'G16PREGSTE_raw', 'G16PREOWRI_raw', 'G16USSRMCC_raw', 'G16USSDKIR_raw',
       'G16USSGSWI_raw', 'G16USSOWRI_raw', 'geometry', 'county_name_x',
       'county_precinct_x', 'matches', 'part1_temp', 'part2_temp',
       'part3_temp', 'county_name_y', 'county_fips', 'precinct', 'G16PRERTRU', 'G16PREDCLI',
       'G16PRELJOH', 'G16PREGSTE', 'G16PREOWRI', 'G16USSRMCC', 'G16USSDKIR',
       'G16USSGSWI', 'G16USSOWRI',
       'precinct_name', 'precinct_code', 'county', 'county_precinct_y']

# %% [markdown]
# Joining RDH final to VEST final

# %%
overlap = df_joined.merge(vest_shp, how = 'outer'
                            , left_on = ['PCTNUM'], right_on = ['PCTNUM']
                            , indicator = True)

# %%
overlap.groupby('_merge').count()
# Out:
#             PCTNUM  PRECINCTNA_x  CDE_COUNTY_x  G16PRERTRU_raw  \
# _merge
# left_only        0             0             0               0
# right_only       0             0             0               0
# both          1469          1469          1469            1469
#
#             G16PREDCLI_raw  G16PRELJOH_raw  G16PREGSTE_raw  G16PREOWRI_raw  \
# _merge
# left_only                0               0               0               0
# right_only               0               0               0               0
# both                  1469            1469            1469            1469
#
#             G16USSRMCC_raw  G16USSDKIR_raw  ...  G16PRERTRU_y  G16PREDCLI_y  \
# _merge                                      ...
# left_only                0               0  ...             0             0
# right_only               0               0  ...             0             0
# both                  1469            1469  ...          1469          1469
#
#             G16PRELJOH_y  G16PREGSTE_y  G16PREOWRI_y  G16USSRMCC_y  \
# _merge
# left_only              0             0             0             0
# right_only             0             0             0             0
# both                1469          1469          1469          1469
#
#             G16USSDKIR_y  G16USSGSWI_y  G16USSOWRI_y  geometry_y
# _merge
# left_only              0             0             0           0
# right_only             0             0             0           0
# both                1469          1469          1469        1469
#
# [3 rows x 47 columns]

# %% [markdown]
# ## Validation

# %% [markdown]
# The election results are what determine the checkbox criteria for validation on the website. The rest of the validation checks we will note in the report as well, but they do not have their own checkboxes.

# %% [markdown]
# ### Election Results

# %%
def validater_row (df, column_List, pct_column_name, county_column_name):
    matching_rows = 0
    different_rows = 0
    diff_list=[]
    election_result_diffs=[]
    
    for j in range(0,len(df.index)):
        same = True
        for i in column_List:
            left_Data = i + "_x"
            right_Data = i + "_y"
            if(df.iloc[j][left_Data]-df.iloc[j][right_Data] != 0):
                same = False
                election_result_diffs.append(i)
        if(same != True):
            different_rows +=1
            diff_list.append(df.iloc[j][county_column_name] + ' ' + df.iloc[j][pct_column_name])
        else:
            matching_rows +=1
    print("There are ", len(df.index)," total rows")
    print(different_rows," of these rows have election result differences")
    print(matching_rows," of these rows are the same")
#     print(diff_list)
    if different_rows >0:
        print("The differences were in these " + str(len(set(election_result_diffs))) + " columns: ", set(election_result_diffs))
    print("")

# %% [markdown]
# We are skipping comparing the write in columns because we know that MEDSL's are wrong here, and VEST's are right, from the earlier checks

# %%
election_column_List = [x for x in vest_shp.columns if 'G16' in x]

# %%
validater_row(overlap,election_column_List, 'PCTNUM', 'county')
# Out:
# There are  1469  total rows
# 8  of these rows have election result differences
# 1461  of these rows are the same
# The differences were in these 9 columns:  {'G16PREGSTE', 'G16USSOWRI', 'G16PRERTRU', 'G16PRELJOH', 'G16PREOWRI', 'G16PREDCLI', 'G16USSGSWI', 'G16USSDKIR', 'G16USSRMCC'}

# %%
overlap.columns
# Out:
# Index(['PCTNUM', 'PRECINCTNA_x', 'CDE_COUNTY_x', 'G16PRERTRU_raw',
#        'G16PREDCLI_raw', 'G16PRELJOH_raw', 'G16PREGSTE_raw', 'G16PREOWRI_raw',
#        'G16USSRMCC_raw', 'G16USSDKIR_raw', 'G16USSGSWI_raw', 'G16USSOWRI_raw',
#        'geometry_x', 'county_name_x', 'county_precinct_x', 'matches',
#        'part1_temp', 'part2_temp', 'part3_temp', 'county_name_y',
#        'county_fips', 'precinct', 'G16PRERTRU_x', 'G16PREDCLI_x',
#        'G16PRELJOH_x', 'G16PREGSTE_x', 'G16PREOWRI_x', 'G16USSRMCC_x',
#        'G16USSDKIR_x', 'G16USSGSWI_x', 'G16USSOWRI_x', 'precinct_name',
#        'precinct_code', 'county', 'county_precinct_y', 'PRECINCTNA_y',
#        'CDE_COUNTY_y', 'G16PRERTRU_y', 'G16PREDCLI_y', 'G16PRELJOH_y',
#        'G16PREGSTE_y', 'G16PREOWRI_y', 'G16USSRMCC_y', 'G16USSDKIR_y',
#        'G16USSGSWI_y', 'G16USSOWRI_y', 'geometry_y', '_merge'],
#       dtype='object')

# %%
overlap.loc[overlap.G16PRERTRU_x != overlap.G16PRERTRU_y][['PCTNUM','PRECINCTNA_x','county','matches',
                                                          'G16PRERTRU_x','G16PRERTRU_y']]
# Out:
#      PCTNUM        PRECINCTNA_x   county                        matches  \
# 64   CH0046           WHETSTONE  Cochise           Cochise Whetstone|46
# 211  CH0020         PIRTLEVILLE  Cochise         Cochise Pirtleville|20
# 213  CH0027  SV BUFFALO SOLDIER  Cochise  Cochise SV Buffalo Soldier|27
# 585  CH0040   SV TOWN & COUNTRY  Cochise   Cochise SV Town & Country|40
# 839  CH0007               BOWIE  Cochise               Cochise Bowie|07
# 875  CH0016            HUACHUCA  Cochise            Cochise Huachuca|16
# 887  CH0039    SV SOLDIER CREEK  Cochise    Cochise SV Soldier Creek|39
#
#      G16PRERTRU_x  G16PRERTRU_y
# 64           1081          1087
# 211           210           211
# 213          1136          1137
# 585           888           889
# 839           125           126
# 875           372           373
# 887           722           723

# %% [markdown]
# These differences are very small... checked them against the SOS results [here](https://apps.azsos.gov/results/2016/General/Cochise.txt) and VEST was correct, not MEDSL.

# %%
#Checks the sums of different columns and prints out the 
def sum_checker (df1,df2, column_List):
    list_max = 0
    for i in column_List:
        df1_sum = df1[i].sum()
        df2_sum = df2[i].sum()
        if (df1_sum==df2_sum):
            print("Column: ", i, " have the same sums")
            
        else:
            diff = abs(df1_sum-df2_sum)
            percent = abs(df1_sum-df2_sum)/df1_sum
            print("Column: ", i)
            print("DataFrame #1 sum is ", str(df1_sum))
            print("DataFrame #2 sum is ", str(df2_sum))
            print("Their (absolute) difference is ",str(diff))
            print("As a percentage of DF1 this is ", str(round(percent*100,5)) + "%")
            if (percent>list_max):
                list_max = percent
            print("")
    print("The max difference (as a percent of the total of one DF column) is: ", str(round(list_max,5)))

# %%
sum_checker(df_joined,vest_shp,election_column_List)
# Out:
# Column:  G16PRERTRU
# DataFrame #1 sum is  1252389
# DataFrame #2 sum is  1252401
# Their (absolute) difference is  12
# As a percentage of DF1 this is  0.00096%
#
# Column:  G16PREDCLI
# DataFrame #1 sum is  1161165
# DataFrame #2 sum is  1161167
# Their (absolute) difference is  2
# As a percentage of DF1 this is  0.00017%
#
# Column:  G16PRELJOH
# DataFrame #1 sum is  106326
# DataFrame #2 sum is  106327
# Their (absolute) difference is  1
# As a percentage of DF1 this is  0.00094%
#
# Column:  G16PREGSTE
# DataFrame #1 sum is  34344
# DataFrame #2 sum is  34345
# Their (absolute) difference is  1
# As a percentage of DF1 this is  0.00291%
#
# Column:  G16PREOWRI
# DataFrame #1 sum is  50415
# DataFrame #2 sum is  50417
# Their (absolute) difference is  2
# As a percentage of DF1 this is  0.00397%
#
# Column:  G16USSRMCC
# DataFrame #1 sum is  1359258
# DataFrame #2 sum is  1359267
# Their (absolute) difference is  9
# As a percentage of DF1 this is  0.00066%
#
# Column:  G16USSDKIR
# DataFrame #1 sum is  1031241
# DataFrame #2 sum is  1031245
# Their (absolute) difference is  4
# As a percentage of DF1 this is  0.00039%
#
# Column:  G16USSGSWI
# DataFrame #1 sum is  138631
# DataFrame #2 sum is  138634
# Their (absolute) difference is  3
# As a percentage of DF1 this is  0.00216%
#
# Column:  G16USSOWRI
# DataFrame #1 sum is  17912
# DataFrame #2 sum is  17914
# Their (absolute) difference is  2
# As a percentage of DF1 this is  0.01117%
#
# The max difference (as a percent of the total of one DF column) is:  0.00011

# %% [markdown]
# ### Geometries

# %%
pdv_shapes_elections_and_shapes = gp.GeoDataFrame(overlap, geometry='geometry_x')
partner_shapes_elections_and_shapes = gp.GeoDataFrame(overlap, geometry='geometry_y')

pdv_shapes_elections_and_shapes.crs=partner_shapes_elections_and_shapes.crs

# %%
print(pdv_shapes_elections_and_shapes.geom_almost_equals(partner_shapes_elections_and_shapes,decimal=1).value_counts())
# Out:
# True    1469
# dtype: int64

# %% [markdown]
# From the above, all precincts match. This is expected since the file is the same.
